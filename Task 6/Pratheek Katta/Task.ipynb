# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\LENOVO\Downloads\Cereals.csv')

df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                   All-Bran   K    C        70        4    1     260    9.0
# 2  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3             Almond_Delight   R    C       110        2    2     200    1.0
# 4    Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    8.0       8     135         0      3     1.0  1.00  33.983679
# 1    7.0       5     320        25      3     1.0  0.33  59.425505
# 2    8.0       0     330        25      3     1.0  0.50  93.704912
# 3   14.0       8      -1        25      3     1.0  0.75  34.384843
# 4   10.5      10      70        25      1     1.0  0.75  29.509541

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.723684
# std     19.139378   1.089020   1.013159   84.318813   2.219038   4.160444
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.500000
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    6.934211   93.657895   28.289474   2.197368   1.030000   0.827500
# std     4.473136   68.502565   22.487813   0.832982   0.151438   0.227204
# ...

# %%
columns=['protein','sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins']

# %%
for col in columns:
    mean_value = df[df[col] >= 0][col].mean()
    df.loc[df[col] < 0, col] = mean_value
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120      3.0    5    15.0    2.0
# 1                    All-Bran   K    C        70      4.0    1   260.0    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50      4.0    0   140.0   14.0
# 3              Almond_Delight   R    C       110      2.0    2   200.0    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110      2.0    2   180.0    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110      2.0    1   250.0    0.0
# 72                       Trix   G    C       110      1.0    1   140.0    0.0
# 73                 Wheat_Chex   R    C       100      3.0    1   230.0    3.0
# 74                   Wheaties   G    C       100      3.0    1   200.0    3.0
# 75        Wheaties_Honey_Gold   G    C       110      2.0    1   200.0    1.0
#
# ...

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.933333
# std     19.139378   1.089020   1.013159   84.318813   2.219038   3.737498
# min     50.000000   1.000000   0.000000    0.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.966667
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    7.040000   96.216216   28.289474   2.197368   1.030000   0.827500
# std     4.377031   66.687384   22.487813   0.832982   0.151438   0.227204
# ...

# %%
for col in columns:
    median_value = df[df[col] >= 0][col].median()
    df.loc[df[col] < 0, col] = median_value
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120      3.0    5    15.0    2.0
# 1                    All-Bran   K    C        70      4.0    1   260.0    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50      4.0    0   140.0   14.0
# 3              Almond_Delight   R    C       110      2.0    2   200.0    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110      2.0    2   180.0    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110      2.0    1   250.0    0.0
# 72                       Trix   G    C       110      1.0    1   140.0    0.0
# 73                 Wheat_Chex   R    C       100      3.0    1   230.0    3.0
# 74                   Wheaties   G    C       100      3.0    1   200.0    3.0
# 75        Wheaties_Honey_Gold   G    C       110      2.0    1   200.0    1.0
#
# ...

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.933333
# std     19.139378   1.089020   1.013159   84.318813   2.219038   3.737498
# min     50.000000   1.000000   0.000000    0.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.966667
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    7.040000   96.216216   28.289474   2.197368   1.030000   0.827500
# std     4.377031   66.687384   22.487813   0.832982   0.151438   0.227204
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      76 non-null     object
#  1   mfr       76 non-null     object
#  2   type      76 non-null     object
#  3   calories  76 non-null     int64
#  4   protein   76 non-null     float64
#  5   fat       76 non-null     int64
#  6   sodium    76 non-null     float64
#  7   fiber     76 non-null     float64
#  8   carbo     76 non-null     float64
#  9   sugars    76 non-null     float64
#  10  potass    76 non-null     float64
#  11  vitamins  76 non-null     float64
#  12  shelf     76 non-null     int64
#  13  weight    76 non-null     float64
#  14  cups      76 non-null     float64
#  15  rating    76 non-null     float64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 9.6+ KB

# %%
print("Number of unique serials: ", df['name'].nunique())
# Out:
# Number of unique serials:  76

# %%
df["mfr"].value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# R     8
# Q     8
# N     5
# A     1
# Name: count, dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# C    73
# H     3
# Name: count, dtype: int64

# %%
worst = df['rating'].idxmin()
best = df['rating'].idxmax()
print("Best Cereal: ", df.loc[best, 'name'])
print("Worst Cereal: ", df.loc[worst, 'name'])
# Out:
# Best Cereal:  All-Bran_with_Extra_Fiber
# Worst Cereal:  Cap'n'Crunch

# %%
df.groupby('type')['rating'].mean()
# Out:
# type
# C    41.734838
# H    56.737708
# Name: rating, dtype: float64

# %%
print("Hot is more preferred")
# Out:
# Hot is more preferred

# %%
min = df['sugars'].idxmin()
max = df['fiber'].idxmax()
print("Highest Fibre: ", df.loc[max, 'name'])
print("Lowest Sugar: ", df.loc[min, 'name'])
# Out:
# Highest Fibre:  All-Bran_with_Extra_Fiber
# Lowest Sugar:  All-Bran_with_Extra_Fiber

# %%
df[df['protein']>3]
# Out:
# Cereals with more than 3g protein
#                                      name mfr type  calories  protein  fat  \
# 1                                All-Bran   K    C        70      4.0    1
# 2               All-Bran_with_Extra_Fiber   K    C        50      4.0    0
# 10                               Cheerios   G    C       110      6.0    2
# 40                                   Life   Q    C       100      4.0    2
# 42                                  Maypo   A    H       100      4.0    1
# 43   Muesli_Raisins,_Dates,_&amp;_Almonds   R    C       150      4.0    3
# 44  Muesli_Raisins,_Peaches,_&amp;_Pecans   R    C       150      4.0    3
# 55                     Quaker_Oat_Squares   Q    C       100      4.0    1
# 56                         Quaker_Oatmeal   Q    H       100      5.0    2
# 66                              Special_K   K    C       110      6.0    0
#
#     sodium  fiber      carbo  sugars  potass  vitamins  shelf  weight  cups  \
# ...

# %%
df[["name","shelf"]]
# Out:
#                          name  shelf
# 0           100%_Natural_Bran      3
# 1                    All-Bran      3
# 2   All-Bran_with_Extra_Fiber      3
# 3              Almond_Delight      3
# 4     Apple_Cinnamon_Cheerios      1
# ..                        ...    ...
# 71                    Triples      3
# 72                       Trix      2
# 73                 Wheat_Chex      1
# 74                   Wheaties      1
# 75        Wheaties_Honey_Gold      1
#
# [76 rows x 2 columns]

# %%
plt.figure(figsize=(10,10))
s=df['shelf'].value_counts().sort_index()
s.plot(kind='bar')
plt.title("Number of Cereals by Display Shelf")
plt.xlabel("Shelf ")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.lineplot(data=df, x='mfr',y= 'sugars')
# Out:
# <Axes: xlabel='mfr', ylabel='sugars'>

# %%
a=df.groupby('mfr')['calories'].mean()
a.head(10)
# Out:
# mfr
# A    100.000000
# G    111.363636
# K    108.695652
# N     90.000000
# P    108.888889
# Q     95.000000
# R    115.000000
# Name: calories, dtype: float64

# %%
df[['calories', 'sugars', 'protein', 'fiber']].mean()
# Out:
# calories    107.368421
# sugars        7.040000
# protein       2.526316
# fiber         2.048684
# dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='sugars', y='calories', data=df)
plt.title('Relationship between Sugar and Calories')
plt.xlabel('Sugar Content (g)')
plt.ylabel('Calories')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='shelf', y='rating', data=df)
plt.xlabel('Display Shelf Level')
plt.ylabel('Cereal Rating')
plt.title('Cereal Rating vs. Display Shelf')
plt.show()
