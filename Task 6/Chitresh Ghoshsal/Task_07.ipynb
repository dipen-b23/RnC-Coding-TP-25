# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Cereals.csv')

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                   All-Bran   K    C        70        4    1     260    9.0
# 2  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3             Almond_Delight   R    C       110        2    2     200    1.0
# 4    Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    8.0       8     135         0      3     1.0  1.00  33.983679
# 1    7.0       5     320        25      3     1.0  0.33  59.425505
# 2    8.0       0     330        25      3     1.0  0.50  93.704912
# 3   14.0       8      -1        25      3     1.0  0.75  34.384843
# 4   10.5      10      70        25      1     1.0  0.75  29.509541

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.723684
# std     19.139378   1.089020   1.013159   84.318813   2.219038   4.160444
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.500000
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    6.934211   93.657895   28.289474   2.197368   1.030000   0.827500
# std     4.473136   68.502565   22.487813   0.832982   0.151438   0.227204
# ...

# %%
for attr in df.columns[3:]:
    #df.replace({attr:{-1, df[attr].mean()}}, inplace= True)
    df[attr]=df[attr].replace(-1,df[attr].mean())

df['name']=df['name'].str.replace('_',' ')

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0          100% Natural Bran   Q    C       120        3    5      15    2.0
# 1                   All-Bran   K    C        70        4    1     260    9.0
# 2  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 3             Almond Delight   R    C       110        2    2     200    1.0
# 4    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars      potass  vitamins  shelf  weight  cups     rating
# 0    8.0     8.0  135.000000         0      3     1.0  1.00  33.983679
# 1    7.0     5.0  320.000000        25      3     1.0  0.33  59.425505
# 2    8.0     0.0  330.000000        25      3     1.0  0.50  93.704912
# 3   14.0     8.0   93.657895        25      3     1.0  0.75  34.384843
# 4   10.5    10.0   70.000000        25      1     1.0  0.75  29.509541

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.930575
# std     19.139378   1.089020   1.013159   84.318813   2.219038   3.737575
# min     50.000000   1.000000   0.000000    0.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.861842
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    7.038608   96.148892   28.289474   2.197368   1.030000   0.827500
# std     4.377048   66.688658   22.487813   0.832982   0.151438   0.227204
# ...

# %%
for i in df.columns[3:]:
   Q1 = df[i].quantile(0.25)
   Q3 = df[i].quantile(0.75)
   IQR = Q3 - Q1
   lower_bound = Q1 - 1.5 * IQR
   upper_bound = Q3 + 1.5 * IQR
   outlier=(df[i]<lower_bound) | (df[i]>upper_bound)
   df.loc[outlier,i]=df[i].median()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2604\751594562.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[outlier,i]=df[i].median()

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0          100% Natural Bran   Q    C       120      3.0    5      15   2.00
# 1                   All-Bran   K    C       110      4.0    1     260   1.75
# 2  All-Bran with Extra Fiber   K    C       110      4.0    0     140   1.75
# 3             Almond Delight   R    C       110      2.0    2     200   1.00
# 4    Apple Cinnamon Cheerios   G    C       110      2.0    2     180   1.50
#
#    carbo  sugars      potass  vitamins  shelf  weight  cups     rating
# 0    8.0     8.0  135.000000        25      3     1.0  1.00  33.983679
# 1    7.0     5.0   90.000000        25      3     1.0  0.33  59.425505
# 2    8.0     0.0   90.000000        25      3     1.0  0.50  40.253086
# 3   14.0     8.0   93.657895        25      3     1.0  0.75  34.384843
# 4   10.5    10.0   70.000000        25      1     1.0  0.75  29.509541

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.236842   2.401316   1.013158  181.381579   1.792105  14.930575
# std      8.099166   0.875670   1.013159   60.186370   1.520220   3.737575
# min     90.000000   1.000000   0.000000   15.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  147.500000   0.750000  12.000000
# 50%    110.000000   2.250000   1.000000  180.000000   1.625000  14.861842
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    120.000000   4.000000   5.000000  320.000000   6.000000  23.000000
#
#           sugars      potass  vitamins      shelf  weight       cups  \
# count  76.000000   76.000000      76.0  76.000000    76.0  76.000000
# mean    7.038608   85.754155      25.0   2.197368     1.0   0.817632
# std     4.377048   48.049515       0.0   0.832982     0.0   0.213478
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      76 non-null     object
#  1   mfr       76 non-null     object
#  2   type      76 non-null     object
#  3   calories  76 non-null     int64
#  4   protein   76 non-null     float64
#  5   fat       76 non-null     int64
#  6   sodium    76 non-null     int64
#  7   fiber     76 non-null     float64
#  8   carbo     76 non-null     float64
#  9   sugars    76 non-null     float64
#  10  potass    76 non-null     float64
#  11  vitamins  76 non-null     int64
#  12  shelf     76 non-null     int64
#  13  weight    76 non-null     float64
#  14  cups      76 non-null     float64
#  15  rating    76 non-null     float64
# dtypes: float64(8), int64(5), object(3)
# memory usage: 9.6+ KB

# %%
print("The number of unique brands: "+str(df['mfr'].value_counts().count()))
# Out:
# The number of unique brands: 7

# %%
print("Number of cereals per manufacturer:\n")
df['mfr'].value_counts().to_frame()
# Out:
# Number of cereals per manufacturer:
#      count
# mfr
# K       23
# G       22
# P        9
# R        8
# Q        8
# N        5
# A        1

# %%
df['type'].value_counts()
# Out:
# type
# C    73
# H     3
# Name: count, dtype: int64

# %%
print("Best rated cereal\n")
df[df['rating']==df['rating'].max()]
# Out:
# Best rated cereal
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 63  Shredded Wheat 'n'Bran   N    C        90      3.0    0     180    4.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 63   19.0     0.0   140.0        25      1     1.0  0.67  74.472949

# %%
print("Worst rated cereal\n")
df[df['rating']==df['rating'].min()]
# Out:
# Worst rated cereal
#            name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 9  Cap'n'Crunch   Q    C       120      1.0    2     220    0.0   12.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 9    12.0    35.0        25      2     1.0  0.75  18.042851

# %%
cold= df.groupby('type')['rating'].mean()
print(cold.to_frame())
print("Hot is more preferred")
# Out:
#          rating
# type
# C     41.002621
# H     56.737708
# Hot is more preferred

# %%
print("Cereals with highest fibres")
df[df['fiber']==df['fiber'].max()]
# Out:
# Cereals with highest fibres
#                      name mfr type  calories  protein  fat  sodium  fiber  \
# 51  Post Nat. Raisin Bran   P    C       120      3.0    1     200    6.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 51   11.0    14.0    90.0        25      3     1.0  0.67  37.840594

# %%
print("Cereals with lowest sugars")
df[df['sugars']==df['sugars'].max()]
# Out:
# Cereals with lowest sugars
#             name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 29  Golden Crisp   P    C       100      2.0    0      45    0.0   11.0
# 65        Smacks   K    C       110      2.0    1      70    1.0    9.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 29    15.0    40.0        25      1     1.0  0.88  35.252444
# 65    15.0    40.0        25      2     1.0  0.75  31.230054

# %%
print("Cereals with more than 3g protein")
df[df['protein']>3]
# Out:
# Cereals with more than 3g protein
#                                      name mfr type  calories  protein  fat  \
# 1                                All-Bran   K    C       110      4.0    1
# 2               All-Bran with Extra Fiber   K    C       110      4.0    0
# 40                                   Life   Q    C       100      4.0    2
# 42                                  Maypo   A    H       100      4.0    1
# 43   Muesli Raisins, Dates, &amp; Almonds   R    C       110      4.0    3
# 44  Muesli Raisins, Peaches, &amp; Pecans   R    C       110      4.0    3
# 55                     Quaker Oat Squares   Q    C       100      4.0    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 1      260   1.75    7.0     5.0    90.0        25      3     1.0  0.33
# 2      140   1.75    8.0     0.0    90.0        25      3     1.0  0.50
# 40     150   2.00   12.0     6.0    95.0        25      2     1.0  0.67
# ...

# %%
df[['name','shelf']].head()
# Out:
#                         name  shelf
# 0          100% Natural Bran      3
# 1                   All-Bran      3
# 2  All-Bran with Extra Fiber      3
# 3             Almond Delight      3
# 4    Apple Cinnamon Cheerios      1

# %%
shelf=df['shelf'].value_counts()
shelf.to_frame()
shelf_df= pd.DataFrame(shelf)
shelf_df
# Out:
#        count
# shelf
# 3         35
# 2         21
# 1         20

# %%
sns.barplot(data= shelf_df, x='shelf', y='count', palette='Dark2')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2604\1750344726.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= shelf_df, x='shelf', y='count', palette='Dark2')
# <Axes: xlabel='shelf', ylabel='count'>

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0          100% Natural Bran   Q    C       120      3.0    5      15   2.00
# 1                   All-Bran   K    C       110      4.0    1     260   1.75
# 2  All-Bran with Extra Fiber   K    C       110      4.0    0     140   1.75
# 3             Almond Delight   R    C       110      2.0    2     200   1.00
# 4    Apple Cinnamon Cheerios   G    C       110      2.0    2     180   1.50
#
#    carbo  sugars      potass  vitamins  shelf  weight  cups     rating
# 0    8.0     8.0  135.000000        25      3     1.0  1.00  33.983679
# 1    7.0     5.0   90.000000        25      3     1.0  0.33  59.425505
# 2    8.0     0.0   90.000000        25      3     1.0  0.50  40.253086
# 3   14.0     8.0   93.657895        25      3     1.0  0.75  34.384843
# 4   10.5    10.0   70.000000        25      1     1.0  0.75  29.509541

# %%
sns.lineplot(data=df, x='mfr',y= 'sugars')
# Out:
# <Axes: xlabel='mfr', ylabel='sugars'>

# %%
sns.barplot(data= df, x='mfr', y='calories', palette=['skyblue'], estimator= np.mean)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2604\1608652884.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= df, x='mfr', y='calories', palette=['skyblue'], estimator= np.mean)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2604\1608652884.py:1: UserWarning:
# The palette list has fewer values (1) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data= df, x='mfr', y='calories', palette=['skyblue'], estimator= np.mean)
# <Axes: xlabel='mfr', ylabel='calories'>

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0          100% Natural Bran   Q    C       120      3.0    5      15   2.00
# 1                   All-Bran   K    C       110      4.0    1     260   1.75
# 2  All-Bran with Extra Fiber   K    C       110      4.0    0     140   1.75
# 3             Almond Delight   R    C       110      2.0    2     200   1.00
# 4    Apple Cinnamon Cheerios   G    C       110      2.0    2     180   1.50
#
#    carbo  sugars      potass  vitamins  shelf  weight  cups     rating
# 0    8.0     8.0  135.000000        25      3     1.0  1.00  33.983679
# 1    7.0     5.0   90.000000        25      3     1.0  0.33  59.425505
# 2    8.0     0.0   90.000000        25      3     1.0  0.50  40.253086
# 3   14.0     8.0   93.657895        25      3     1.0  0.75  34.384843
# 4   10.5    10.0   70.000000        25      1     1.0  0.75  29.509541

# %%
avg_by_mfr = df.groupby('mfr')[['calories', 'sugars', 'protein', 'fiber', 'fat', 'carbo', 'sodium', 'potass']].mean()
avg= pd.DataFrame(avg_by_mfr)
type(avg)
avg
# Out:
#        calories    sugars   protein     fiber       fat      carbo  \
# mfr
# A    100.000000  3.000000  4.000000  0.000000  1.000000  16.000000
# G    108.181818  7.954545  2.159091  1.272727  1.363636  14.727273
# K    108.260870  7.565217  2.500000  1.891304  0.608696  15.130435
# N     96.000000  1.000000  2.600000  2.800000  0.000000  18.200000
# P    108.888889  8.777778  2.444444  2.777778  0.888889  13.222222
# Q    110.000000  6.241776  2.312500  1.337500  1.750000  11.965461
# R    105.000000  6.125000  2.500000  1.875000  1.250000  17.625000
#
#          sodium      potass
# mfr
# A    180.000000   95.000000
# G    200.454545   85.227273
# K    190.434783   76.086957
# N    127.000000  107.731579
# P    146.111111   95.000000
# Q    160.000000   74.375000
# R    198.125000  101.082237

# %%
for i in avg.index:
    plt.figure(figsize=(6,4))
    plt.bar(avg.columns,avg.loc[i], color='skyblue')
    plt.title("Avg Nutrition for Manufacturer " + str(i))
    plt.xlabel("Nutrients")
    plt.ylabel("Average")

# %%
sns.lineplot(data=df, x='sugars', y='calories')
# Out:
# <Axes: xlabel='sugars', ylabel='calories'>

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0          100% Natural Bran   Q    C       120      3.0    5      15   2.00
# 1                   All-Bran   K    C       110      4.0    1     260   1.75
# 2  All-Bran with Extra Fiber   K    C       110      4.0    0     140   1.75
# 3             Almond Delight   R    C       110      2.0    2     200   1.00
# 4    Apple Cinnamon Cheerios   G    C       110      2.0    2     180   1.50
#
#    carbo  sugars      potass  vitamins  shelf  weight  cups     rating
# 0    8.0     8.0  135.000000        25      3     1.0  1.00  33.983679
# 1    7.0     5.0   90.000000        25      3     1.0  0.33  59.425505
# 2    8.0     0.0   90.000000        25      3     1.0  0.50  40.253086
# 3   14.0     8.0   93.657895        25      3     1.0  0.75  34.384843
# 4   10.5    10.0   70.000000        25      1     1.0  0.75  29.509541

# %%
sort_rating= df.sort_values('rating')
sns.lineplot(data=df, y=sort_rating['rating'], x='sugars')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 2
#       1 sort_rating= df.sort_values('rating')
# ----> 2 sns.lineplot(data=df, y=sort_rating['rating'], x=['sugars', 'fiber'])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
# ...

# %%
print("As sugar decreases rating increases")
# Out:
# As sugar decreases rating increases

# %%
sns.lineplot(data=df, y=sort_rating['rating'], x='fiber')
# Out:
# <Axes: xlabel='fiber', ylabel='rating'>

# %%
print("Healthy marketed cereals have more ratings")
# Out:
# Healthy marketed cereals have more ratings

# %%
sns.lineplot(data=df, x='shelf', y='rating')
# Out:
# <Axes: xlabel='shelf', ylabel='rating'>
